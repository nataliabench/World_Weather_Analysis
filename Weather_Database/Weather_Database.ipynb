# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/00/mnhwy8t93ws1rpd98dt_7xqw0000gn/T/ipykernel_98199/2850662384.py in <module>
#       1 # Import dependencies
# ----> 2 from citipy import citipy
#       3 import pandas as pd
#       4 import numpy as np
#       5 import json
#
# ModuleNotFoundError: No module named 'citipy'

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# One can only unzip a zipped tuple once before it is removed from the computer's memory. 
# Make sure to unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(87.43567355017439, -130.42084619166235), (-56.42692918357154, 150.6551401074056), (-38.83687369275977, -18.565623514206237), (25.73639414754568, -137.81539667452), (-48.369220934252, 126.58593084425013), (13.82043944321039, 173.9301894566476), (-24.374113876277193, -31.059244644998586), (-65.64039162402575, -159.11788710696834), (81.21066489888753, -166.28498329116812), (55.84868001132304, 73.93069013049848), (-75.54121437269932, -62.43762160024089), (-61.911554990284706, -140.26756302787294), (-42.01773737570418, 102.591467966376), (-54.79217150374996, -69.3945790637835), (-37.33814710909199, 84.01090720093947), (-85.51816947624027, 99.85460348809818), (-5.859348251180009, -21.499735915906683), (48.701969261459055, 26.089103022373877), (85.86934546295683, 168.23492690606662), (-23.066792935954254, 167.1208078665294), (51.38865487931315, -175.95837849717637), (-33.95004527944688, 67.57015373870556), (83.61072357202374, 31.694351531013893), (54.19999252864662, 12.599016270699991), (-6.651823264744365, -102.64812835861031), (31.002834281019545, -12.728029066799735), (-69.08850336528857, -107.46555515420027), (-5.735006589600232, 82.54106118296369), (-88.55714909260752, 80.07985827883812), (-50.901989053572414, 11.241776184486952), (-38.293149347437364, 147.31749101260016), (53.438360617177835, 146.74208641956153), (-45.82998536997497, 5.05514838924239), (-32.29177701646776, -2.3315244647747306), (3.0443855298031366, 4.1683567148213285), (-5.213559038678966, -100.0304310673366), (61.47415906099553, 93.10823027407076), (-49.38672562923955, 123.41096982079029), (55.6729680336031, 168.14146277055409), (-57.55364369315806, -27.602800285770996), (72.76010252576893, 124.93827557782754), (-46.6291754962949, -132.25104484786192), (41.465036022597104, 28.534531324273786), (-70.78490762404483, -72.1619130436044), (-6.8388238119575675, -108.29878013953359), (-88.124085035938, 15.700677702432841), (84.01940395390199, -68.63896800905022), (68.55662639158263, 87.40441575400263), (40.35316173638162, 31.482150879242397), (-20.74252003681454, -39.93841466143431), (2.709043968932363, 21.53652305028828), (-26.700076329388068, 164.405783958057), (-17.21375038965938, 52.55765385804625), (32.33887807792483, 36.19532155379255), (-40.32240332476707, 149.6820605823931), (-15.960513919444736, 97.62954089413904), (25.08878607093132, 126.19805109881025), (-26.98302125982905, 13.13611294355232), (65.58430948577228, 8.625360762536559), (-25.90213428285938, 115.72752788231656), (28.180049206490708, -131.7868504813743), (13.091581418833727, 118.27873664408673), (19.486714012221782, 158.31462291561405), (-57.42947285681677, -3.641588284716221), (44.44066352609323, 3.0592979706587187), (33.58175037751046, -114.83362309400981), (-38.202284917445944, -67.9154656806478), (79.47026267385945, -67.64708739589796), (-15.729010457736763, -45.436874643417724), (-70.03498447549724, 69.53371269122499), (-73.42458151400935, 31.939408772855757), (41.66362336063534, -146.27250663206573), (-40.92561367858551, 62.887982639944994), (-14.817395730808528, -58.9894974973065), (-62.14844824919304, -72.34717221376268), (-64.46629171382827, 120.6251374720407), (-65.55295087092877, 69.96211241629146), (23.32409467971135, -16.58156393666829), (87.93339429603566, -51.62313080768104), (-83.5522869712007, 20.613234648323953), (-87.09611014396927, 109.69410332679001), (54.14468307184654, 175.7145104878183), (6.463400637908322, 6.130622492526925), (-2.6980564528262647, 65.68449799196785), (-71.659295120186, -40.436729192939055), (-69.88188576593977, 50.14198794012944), (-86.96132088911831, -42.90690666399607), (-9.11712487252899, 37.42717850406211), (8.16177452251597, 33.11004372992508), (69.15648070441102, 105.18403042543866), (-38.87760712221264, 20.201217177383853), (44.259217462268765, 131.14599941090762), (-58.19616758447186, -161.77415632880715), (74.68547218586173, 149.85498252856934), (80.864615441701, -173.7498601875281), (-35.51222907352474, 118.19954244676796), (-21.9541194204766 ...

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/00/mnhwy8t93ws1rpd98dt_7xqw0000gn/T/ipykernel_98199/1655015922.py in <module>
#       4 # Identify the nearest city for each latitude and longitude combination.
#       5 for coordinate in coordinates:
# ----> 6     city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
#       7
#       8     # If the city is unique, then we will add it to the cities list.
#
# NameError: name 'citipy' is not defined

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/00/mnhwy8t93ws1rpd98dt_7xqw0000gn/T/ipykernel_98199/2571290649.py in <module>
# ----> 1 url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#
# NameError: name 'weather_api_key' is not defined

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 0

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
